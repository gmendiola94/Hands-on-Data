# %% [markdown]
# ## Day 10: Cathode-Ray Tube
# [Link to puzzle](https://adventofcode.com/2022/day/10)

# %%
from collections import defaultdict

# Read input file
path = 'input/day10.txt'

with open(path, 'r', encoding='utf-8') as file:
    input = file.read().splitlines()

# %% [markdown]
# #### Part 1

# %%
# Initial variables for the X register and cycle number
xValue = 1
cycle = 0
cycleDict = defaultdict(int)


def calculate_register_values():
    global xValue, cycle
    for instruction in input:
        # Depending of the input the register increases
        if instruction[0] == "n":
            cycle += 1
            cycleDict[cycle] = xValue
        elif instruction[0] == "a":
            for i in [1, 2]:
                if i == 1:
                    cycle += 1
                    cycleDict[cycle] = xValue
                else:
                    cycle += 1
                    xValue += int(instruction.split(" ")[1])
                    cycleDict[cycle] = xValue

    # Calculate the sum of signal strengths DURING each 20th cycle
    return sum([cycleDict[key-1]*key for key in cycleDict.keys() if key
               in (20, 60, 100, 140, 180, 220)])


calculate_register_values()
# Out:
# 12980

# %% [markdown]
# #### Part 2

# %% [markdown]
# ##### Logic only

# %%
crt = ""
crtIdx = 0
cycleDict[0] = 1  # Add key 0 to delay output one cycle

for i in range(1, len(cycleDict)):
    # Sprite starting location (sprite width = 3)
    spriteLoc = cycleDict[crtIdx]

    # Find out whether CRT index is in sprite position
    crtVal = "#" if spriteLoc-1 <= crtIdx % 40 <= spriteLoc+1 else "."
    crt += crtVal

    # Enter line break when crt index reached 40th position
    if not (crtIdx+1) % 40:
        crt += "\n"
    crtIdx += 1

print(crt)
# Out:
# ###..###....##.#....####.#..#.#....###..
# #..#.#..#....#.#....#....#..#.#....#..#.
# ###..#..#....#.#....###..#..#.#....#..#.
# #..#.###.....#.#....#....#..#.#....###..
# #..#.#.#..#..#.#....#....#..#.#....#....
# ###..#..#..##..####.#.....##..####.#....

# %% [markdown]
# ##### With cycle grid and outputs

# %%
width, height = 40, 6
newCycles = (40, 80, 120, 160, 200, 240)
gridCycles = []

for i in range(height):
    gridCycles.append(f"Cycle {newCycles[i]-(width-1)} -> " +
                      "#"*width + f" <- Cycle {newCycles[i]}")

gridCycles
# Out:
# ['Cycle 1 -> ######################################## <- Cycle 40',
#  'Cycle 41 -> ######################################## <- Cycle 80',
#  'Cycle 81 -> ######################################## <- Cycle 120',
#  'Cycle 121 -> ######################################## <- Cycle 160',
#  'Cycle 161 -> ######################################## <- Cycle 200',
#  'Cycle 201 -> ######################################## <- Cycle 240']

# %%
crt = ""
currentCrtRow = ""
crtIdx = 0
cycleDict[0] = 1  # Add key 0 to delay output one cycle

for i in range(1, len(cycleDict)):
    # Sprite starting location (sprite width = 3)
    spriteLoc = cycleDict[crtIdx]
    # Draw sprite line
    spriteLine = ["."]*width
    # Draw sprites
    if spriteLoc >= 1:
        spriteLine[spriteLoc-1:spriteLoc+2] = "###"
    else:
        spriteLine[0:spriteLoc+2] = "###"[:spriteLoc+2]

    # Join sprite row
    concatSpriteLine = "".join(spriteLine)

    # Find out whether CRT index is in sprite position
    crtVal = "#" if spriteLoc-1 <= crtIdx % 40 <= spriteLoc+1 else "."
    crt += crtVal
    currentCrtRow += crtVal

    # Print output
    print(f"\n End of cycle {i-1}: finish executing {spriteLoc}\
          \n Starting sprite row: {concatSpriteLine}\
          \n During cycle {i}: CRT draws in position {crtIdx % 40}\
          \n Current CRT row: {currentCrtRow}")

    # Enter line break when crt index reached 40th position
    if not (crtIdx+1) % 40:
        crt += "\n"
        currentCrtRow = ""
    crtIdx += 1
# Out:
#  End of cycle 0: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 1: CRT draws in position 0
#  Current CRT row: #
#
#  End of cycle 1: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 2: CRT draws in position 1
#  Current CRT row: ##
#
#  End of cycle 2: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 3: CRT draws in position 2
#  Current CRT row: ###
#
#  End of cycle 3: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 4: CRT draws in position 3
#  Current CRT row: ###.
#
#  End of cycle 4: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 5: CRT draws in position 4
#  Current CRT row: ###..
#
#  End of cycle 5: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 6: CRT draws in position 5
#  Current CRT row: ###..#
#
#  End of cycle 6: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 7: CRT draws in position 6
#  Current CRT row: ###..##
#
#  End of cycle 7: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 8: CRT draws in position 7
#  Current CRT row: ###..###
#
#  End of cycle 8: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 9: CRT draws in position 8
#  Current CRT row: ###..###.
#
#  End of cycle 9: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 10: CRT draws in position 9
#  Current CRT row: ###..###..
#
#  End of cycle 10: finish executing 16
#  Starting sprite row: ...............###......................
#  During cycle 11: CRT draws in position 10
#  Current CRT row: ###..###...
#
#  End of cycle 11: finish executing 16
#  Starting sprite row: ...............###......................
#  During cycle 12: CRT draws in position 11
#  Current CRT row: ###..###....
#
#  End of cycle 12: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 13: CRT draws in position 12
#  Current CRT row: ###..###....#
#
#  End of cycle 13: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 14: CRT draws in position 13
#  Current CRT row: ###..###....##
#
#  End of cycle 14: finish executing 16
#  Starting sprite row: ...............###......................
#  During cycle 15: CRT draws in position 14
#  Current CRT row: ###..###....##.
#
#  End of cycle 15: finish executing 16
#  Starting sprite row: ...............###......................
#  During cycle 16: CRT draws in position 15
#  Current CRT row: ###..###....##.#
#
#  End of cycle 16: finish executing 10
#  Starting sprite row: .........###............................
#  During cycle 17: CRT draws in position 16
#  Current CRT row: ###..###....##.#.
#
#  End of cycle 17: finish executing 10
#  Starting sprite row: .........###............................
#  During cycle 18: CRT draws in position 17
#  Current CRT row: ###..###....##.#..
#
#  End of cycle 18: finish executing 21
#  Starting sprite row: ....................###.................
#  During cycle 19: CRT draws in position 18
#  Current CRT row: ###..###....##.#...
#
#  End of cycle 19: finish executing 21
#  Starting sprite row: ....................###.................
#  During cycle 20: CRT draws in position 19
#  Current CRT row: ###..###....##.#....
#
#  End of cycle 20: finish executing 20
#  Starting sprite row: ...................###..................
#  During cycle 21: CRT draws in position 20
#  Current CRT row: ###..###....##.#....#
#
#  End of cycle 21: finish executing 20
#  Starting sprite row: ...................###..................
#  During cycle 22: CRT draws in position 21
#  Current CRT row: ###..###....##.#....##
#
#  End of cycle 22: finish executing 22
#  Starting sprite row: .....................###................
#  During cycle 23: CRT draws in position 22
#  Current CRT row: ###..###....##.#....###
#
#  End of cycle 23: finish executing 22
#  Starting sprite row: .....................###................
#  During cycle 24: CRT draws in position 23
#  Current CRT row: ###..###....##.#....####
#
#  End of cycle 24: finish executing 26
#  Starting sprite row: .........................###............
#  During cycle 25: CRT draws in position 24
#  Current CRT row: ###..###....##.#....####.
#
#  End of cycle 25: finish executing 26
#  Starting sprite row: .........................###............
#  During cycle 26: CRT draws in position 25
#  Current CRT row: ###..###....##.#....####.#
#
#  End of cycle 26: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 27: CRT draws in position 26
#  Current CRT row: ###..###....##.#....####.#.
#
#  End of cycle 27: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 28: CRT draws in position 27
#  Current CRT row: ###..###....##.#....####.#..
#
#  End of cycle 28: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 29: CRT draws in position 28
#  Current CRT row: ###..###....##.#....####.#..#
#
#  End of cycle 29: finish executing 31
#  Starting sprite row: ..............................###.......
#  During cycle 30: CRT draws in position 29
#  Current CRT row: ###..###....##.#....####.#..#.
#
#  End of cycle 30: finish executing 31
#  Starting sprite row: ..............................###.......
#  During cycle 31: CRT draws in position 30
#  Current CRT row: ###..###....##.#....####.#..#.#
#
#  End of cycle 31: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 32: CRT draws in position 31
#  Current CRT row: ###..###....##.#....####.#..#.#.
#
#  End of cycle 32: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 33: CRT draws in position 32
#  Current CRT row: ###..###....##.#....####.#..#.#..
#
#  End of cycle 33: finish executing 3
#  Starting sprite row: ..###...................................
#  During cycle 34: CRT draws in position 33
#  Current CRT row: ###..###....##.#....####.#..#.#...
#
#  End of cycle 34: finish executing 3
#  Starting sprite row: ..###...................................
#  During cycle 35: CRT draws in position 34
#  Current CRT row: ###..###....##.#....####.#..#.#....
#
#  End of cycle 35: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 36: CRT draws in position 35
#  Current CRT row: ###..###....##.#....####.#..#.#....#
#
#  End of cycle 36: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 37: CRT draws in position 36
#  Current CRT row: ###..###....##.#....####.#..#.#....##
#
#  End of cycle 37: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 38: CRT draws in position 37
#  Current CRT row: ###..###....##.#....####.#..#.#....###
#
#  End of cycle 38: finish executing -1
#  Starting sprite row: #.......................................
#  During cycle 39: CRT draws in position 38
#  Current CRT row: ###..###....##.#....####.#..#.#....###.
#
#  End of cycle 39: finish executing -1
#  Starting sprite row: #.......................................
#  During cycle 40: CRT draws in position 39
#  Current CRT row: ###..###....##.#....####.#..#.#....###..
#
#  End of cycle 40: finish executing -1
#  Starting sprite row: #.......................................
#  During cycle 41: CRT draws in position 0
#  Current CRT row: #
#
#  End of cycle 41: finish executing -1
#  Starting sprite row: #.......................................
#  During cycle 42: CRT draws in position 1
#  Current CRT row: #.
#
#  End of cycle 42: finish executing -1
#  Starting sprite row: #.......................................
#  During cycle 43: CRT draws in position 2
#  Current CRT row: #..
#
#  End of cycle 43: finish executing 2
#  Starting sprite row: .###....................................
#  During cycle 44: CRT draws in position 3
#  Current CRT row: #..#
#
#  End of cycle 44: finish executing 2
#  Starting sprite row: .###....................................
#  During cycle 45: CRT draws in position 4
#  Current CRT row: #..#.
#
#  End of cycle 45: finish executing 4
#  Starting sprite row: ...###..................................
#  During cycle 46: CRT draws in position 5
#  Current CRT row: #..#.#
#
#  End of cycle 46: finish executing 4
#  Starting sprite row: ...###..................................
#  During cycle 47: CRT draws in position 6
#  Current CRT row: #..#.#.
#
#  End of cycle 47: finish executing 9
#  Starting sprite row: ........###.............................
#  During cycle 48: CRT draws in position 7
#  Current CRT row: #..#.#..
#
#  End of cycle 48: finish executing 9
#  Starting sprite row: ........###.............................
#  During cycle 49: CRT draws in position 8
#  Current CRT row: #..#.#..#
#
#  End of cycle 49: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 50: CRT draws in position 9
#  Current CRT row: #..#.#..#.
#
#  End of cycle 50: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 51: CRT draws in position 10
#  Current CRT row: #..#.#..#..
#
#  End of cycle 51: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 52: CRT draws in position 11
#  Current CRT row: #..#.#..#...
#
#  End of cycle 52: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 53: CRT draws in position 12
#  Current CRT row: #..#.#..#....
#
#  End of cycle 53: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 54: CRT draws in position 13
#  Current CRT row: #..#.#..#....#
#
#  End of cycle 54: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 55: CRT draws in position 14
#  Current CRT row: #..#.#..#....#.
#
#  End of cycle 55: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 56: CRT draws in position 15
#  Current CRT row: #..#.#..#....#.#
#
#  End of cycle 56: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 57: CRT draws in position 16
#  Current CRT row: #..#.#..#....#.#.
#
#  End of cycle 57: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 58: CRT draws in position 17
#  Current CRT row: #..#.#..#....#.#..
#
#  End of cycle 58: finish executing 21
#  Starting sprite row: ....................###.................
#  During cycle 59: CRT draws in position 18
#  Current CRT row: #..#.#..#....#.#...
#
#  End of cycle 59: finish executing 21
#  Starting sprite row: ....................###.................
#  During cycle 60: CRT draws in position 19
#  Current CRT row: #..#.#..#....#.#....
#
#  End of cycle 60: finish executing 19
#  Starting sprite row: ..................###...................
#  During cycle 61: CRT draws in position 20
#  Current CRT row: #..#.#..#....#.#....#
#
#  End of cycle 61: finish executing 19
#  Starting sprite row: ..................###...................
#  During cycle 62: CRT draws in position 21
#  Current CRT row: #..#.#..#....#.#....#.
#
#  End of cycle 62: finish executing 13
#  Starting sprite row: ............###.........................
#  During cycle 63: CRT draws in position 22
#  Current CRT row: #..#.#..#....#.#....#..
#
#  End of cycle 63: finish executing 13
#  Starting sprite row: ............###.........................
#  During cycle 64: CRT draws in position 23
#  Current CRT row: #..#.#..#....#.#....#...
#
#  End of cycle 64: finish executing 26
#  Starting sprite row: .........................###............
#  During cycle 65: CRT draws in position 24
#  Current CRT row: #..#.#..#....#.#....#....
#
#  End of cycle 65: finish executing 26
#  Starting sprite row: .........................###............
#  During cycle 66: CRT draws in position 25
#  Current CRT row: #..#.#..#....#.#....#....#
#
#  End of cycle 66: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 67: CRT draws in position 26
#  Current CRT row: #..#.#..#....#.#....#....#.
#
#  End of cycle 67: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 68: CRT draws in position 27
#  Current CRT row: #..#.#..#....#.#....#....#..
#
#  End of cycle 68: finish executing 27
#  Starting sprite row: ..........................###...........
#  During cycle 69: CRT draws in position 28
#  Current CRT row: #..#.#..#....#.#....#....#..#
#
#  End of cycle 69: finish executing 27
#  Starting sprite row: ..........................###...........
#  During cycle 70: CRT draws in position 29
#  Current CRT row: #..#.#..#....#.#....#....#..#.
#
#  End of cycle 70: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 71: CRT draws in position 30
#  Current CRT row: #..#.#..#....#.#....#....#..#.#
#
#  End of cycle 71: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 72: CRT draws in position 31
#  Current CRT row: #..#.#..#....#.#....#....#..#.#.
#
#  End of cycle 72: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 73: CRT draws in position 32
#  Current CRT row: #..#.#..#....#.#....#....#..#.#..
#
#  End of cycle 73: finish executing 24
#  Starting sprite row: .......................###..............
#  During cycle 74: CRT draws in position 33
#  Current CRT row: #..#.#..#....#.#....#....#..#.#...
#
#  End of cycle 74: finish executing 24
#  Starting sprite row: .......................###..............
#  During cycle 75: CRT draws in position 34
#  Current CRT row: #..#.#..#....#.#....#....#..#.#....
#
#  End of cycle 75: finish executing 34
#  Starting sprite row: .................................###....
#  During cycle 76: CRT draws in position 35
#  Current CRT row: #..#.#..#....#.#....#....#..#.#....#
#
#  End of cycle 76: finish executing 34
#  Starting sprite row: .................................###....
#  During cycle 77: CRT draws in position 36
#  Current CRT row: #..#.#..#....#.#....#....#..#.#....#.
#
#  End of cycle 77: finish executing 39
#  Starting sprite row: ......................................###
#  During cycle 78: CRT draws in position 37
#  Current CRT row: #..#.#..#....#.#....#....#..#.#....#..
#
#  End of cycle 78: finish executing 39
#  Starting sprite row: ......................................###
#  During cycle 79: CRT draws in position 38
#  Current CRT row: #..#.#..#....#.#....#....#..#.#....#..#
#
#  End of cycle 79: finish executing 0
#  Starting sprite row: ##......................................
#  During cycle 80: CRT draws in position 39
#  Current CRT row: #..#.#..#....#.#....#....#..#.#....#..#.
#
#  End of cycle 80: finish executing 0
#  Starting sprite row: ##......................................
#  During cycle 81: CRT draws in position 0
#  Current CRT row: #
#
#  End of cycle 81: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 82: CRT draws in position 1
#  Current CRT row: ##
#
#  End of cycle 82: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 83: CRT draws in position 2
#  Current CRT row: ###
#
#  End of cycle 83: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 84: CRT draws in position 3
#  Current CRT row: ###.
#
#  End of cycle 84: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 85: CRT draws in position 4
#  Current CRT row: ###..
#
#  End of cycle 85: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 86: CRT draws in position 5
#  Current CRT row: ###..#
#
#  End of cycle 86: finish executing 9
#  Starting sprite row: ........###.............................
#  During cycle 87: CRT draws in position 6
#  Current CRT row: ###..#.
#
#  End of cycle 87: finish executing 9
#  Starting sprite row: ........###.............................
#  During cycle 88: CRT draws in position 7
#  Current CRT row: ###..#..
#
#  End of cycle 88: finish executing 9
#  Starting sprite row: ........###.............................
#  During cycle 89: CRT draws in position 8
#  Current CRT row: ###..#..#
#
#  End of cycle 89: finish executing 4
#  Starting sprite row: ...###..................................
#  During cycle 90: CRT draws in position 9
#  Current CRT row: ###..#..#.
#
#  End of cycle 90: finish executing 4
#  Starting sprite row: ...###..................................
#  During cycle 91: CRT draws in position 10
#  Current CRT row: ###..#..#..
#
#  End of cycle 91: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 92: CRT draws in position 11
#  Current CRT row: ###..#..#...
#
#  End of cycle 92: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 93: CRT draws in position 12
#  Current CRT row: ###..#..#....
#
#  End of cycle 93: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 94: CRT draws in position 13
#  Current CRT row: ###..#..#....#
#
#  End of cycle 94: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 95: CRT draws in position 14
#  Current CRT row: ###..#..#....#.
#
#  End of cycle 95: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 96: CRT draws in position 15
#  Current CRT row: ###..#..#....#.#
#
#  End of cycle 96: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 97: CRT draws in position 16
#  Current CRT row: ###..#..#....#.#.
#
#  End of cycle 97: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 98: CRT draws in position 17
#  Current CRT row: ###..#..#....#.#..
#
#  End of cycle 98: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 99: CRT draws in position 18
#  Current CRT row: ###..#..#....#.#...
#
#  End of cycle 99: finish executing 21
#  Starting sprite row: ....................###.................
#  During cycle 100: CRT draws in position 19
#  Current CRT row: ###..#..#....#.#....
#
#  End of cycle 100: finish executing 21
#  Starting sprite row: ....................###.................
#  During cycle 101: CRT draws in position 20
#  Current CRT row: ###..#..#....#.#....#
#
#  End of cycle 101: finish executing 21
#  Starting sprite row: ....................###.................
#  During cycle 102: CRT draws in position 21
#  Current CRT row: ###..#..#....#.#....##
#
#  End of cycle 102: finish executing 21
#  Starting sprite row: ....................###.................
#  During cycle 103: CRT draws in position 22
#  Current CRT row: ###..#..#....#.#....###
#
#  End of cycle 103: finish executing 21
#  Starting sprite row: ....................###.................
#  During cycle 104: CRT draws in position 23
#  Current CRT row: ###..#..#....#.#....###.
#
#  End of cycle 104: finish executing 21
#  Starting sprite row: ....................###.................
#  During cycle 105: CRT draws in position 24
#  Current CRT row: ###..#..#....#.#....###..
#
#  End of cycle 105: finish executing 24
#  Starting sprite row: .......................###..............
#  During cycle 106: CRT draws in position 25
#  Current CRT row: ###..#..#....#.#....###..#
#
#  End of cycle 106: finish executing 24
#  Starting sprite row: .......................###..............
#  During cycle 107: CRT draws in position 26
#  Current CRT row: ###..#..#....#.#....###..#.
#
#  End of cycle 107: finish executing 24
#  Starting sprite row: .......................###..............
#  During cycle 108: CRT draws in position 27
#  Current CRT row: ###..#..#....#.#....###..#..
#
#  End of cycle 108: finish executing 27
#  Starting sprite row: ..........................###...........
#  During cycle 109: CRT draws in position 28
#  Current CRT row: ###..#..#....#.#....###..#..#
#
#  End of cycle 109: finish executing 27
#  Starting sprite row: ..........................###...........
#  During cycle 110: CRT draws in position 29
#  Current CRT row: ###..#..#....#.#....###..#..#.
#
#  End of cycle 110: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 111: CRT draws in position 30
#  Current CRT row: ###..#..#....#.#....###..#..#.#
#
#  End of cycle 111: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 112: CRT draws in position 31
#  Current CRT row: ###..#..#....#.#....###..#..#.#.
#
#  End of cycle 112: finish executing 37
#  Starting sprite row: ....................................###.
#  During cycle 113: CRT draws in position 32
#  Current CRT row: ###..#..#....#.#....###..#..#.#..
#
#  End of cycle 113: finish executing 37
#  Starting sprite row: ....................................###.
#  During cycle 114: CRT draws in position 33
#  Current CRT row: ###..#..#....#.#....###..#..#.#...
#
#  End of cycle 114: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 115: CRT draws in position 34
#  Current CRT row: ###..#..#....#.#....###..#..#.#....
#
#  End of cycle 115: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 116: CRT draws in position 35
#  Current CRT row: ###..#..#....#.#....###..#..#.#....#
#
#  End of cycle 116: finish executing 16
#  Starting sprite row: ...............###......................
#  During cycle 117: CRT draws in position 36
#  Current CRT row: ###..#..#....#.#....###..#..#.#....#.
#
#  End of cycle 117: finish executing 16
#  Starting sprite row: ...............###......................
#  During cycle 118: CRT draws in position 37
#  Current CRT row: ###..#..#....#.#....###..#..#.#....#..
#
#  End of cycle 118: finish executing 37
#  Starting sprite row: ....................................###.
#  During cycle 119: CRT draws in position 38
#  Current CRT row: ###..#..#....#.#....###..#..#.#....#..#
#
#  End of cycle 119: finish executing 37
#  Starting sprite row: ....................................###.
#  During cycle 120: CRT draws in position 39
#  Current CRT row: ###..#..#....#.#....###..#..#.#....#..#.
#
#  End of cycle 120: finish executing -1
#  Starting sprite row: #.......................................
#  During cycle 121: CRT draws in position 0
#  Current CRT row: #
#
#  End of cycle 121: finish executing -1
#  Starting sprite row: #.......................................
#  During cycle 122: CRT draws in position 1
#  Current CRT row: #.
#
#  End of cycle 122: finish executing 4
#  Starting sprite row: ...###..................................
#  During cycle 123: CRT draws in position 2
#  Current CRT row: #..
#
#  End of cycle 123: finish executing 4
#  Starting sprite row: ...###..................................
#  During cycle 124: CRT draws in position 3
#  Current CRT row: #..#
#
#  End of cycle 124: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 125: CRT draws in position 4
#  Current CRT row: #..#.
#
#  End of cycle 125: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 126: CRT draws in position 5
#  Current CRT row: #..#.#
#
#  End of cycle 126: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 127: CRT draws in position 6
#  Current CRT row: #..#.##
#
#  End of cycle 127: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 128: CRT draws in position 7
#  Current CRT row: #..#.###
#
#  End of cycle 128: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 129: CRT draws in position 8
#  Current CRT row: #..#.###.
#
#  End of cycle 129: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 130: CRT draws in position 9
#  Current CRT row: #..#.###..
#
#  End of cycle 130: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 131: CRT draws in position 10
#  Current CRT row: #..#.###...
#
#  End of cycle 131: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 132: CRT draws in position 11
#  Current CRT row: #..#.###....
#
#  End of cycle 132: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 133: CRT draws in position 12
#  Current CRT row: #..#.###.....
#
#  End of cycle 133: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 134: CRT draws in position 13
#  Current CRT row: #..#.###.....#
#
#  End of cycle 134: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 135: CRT draws in position 14
#  Current CRT row: #..#.###.....#.
#
#  End of cycle 135: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 136: CRT draws in position 15
#  Current CRT row: #..#.###.....#.#
#
#  End of cycle 136: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 137: CRT draws in position 16
#  Current CRT row: #..#.###.....#.#.
#
#  End of cycle 137: finish executing 7
#  Starting sprite row: ......###...............................
#  During cycle 138: CRT draws in position 17
#  Current CRT row: #..#.###.....#.#..
#
#  End of cycle 138: finish executing 7
#  Starting sprite row: ......###...............................
#  During cycle 139: CRT draws in position 18
#  Current CRT row: #..#.###.....#.#...
#
#  End of cycle 139: finish executing 21
#  Starting sprite row: ....................###.................
#  During cycle 140: CRT draws in position 19
#  Current CRT row: #..#.###.....#.#....
#
#  End of cycle 140: finish executing 21
#  Starting sprite row: ....................###.................
#  During cycle 141: CRT draws in position 20
#  Current CRT row: #..#.###.....#.#....#
#
#  End of cycle 141: finish executing 26
#  Starting sprite row: .........................###............
#  During cycle 142: CRT draws in position 21
#  Current CRT row: #..#.###.....#.#....#.
#
#  End of cycle 142: finish executing 26
#  Starting sprite row: .........................###............
#  During cycle 143: CRT draws in position 22
#  Current CRT row: #..#.###.....#.#....#..
#
#  End of cycle 143: finish executing 26
#  Starting sprite row: .........................###............
#  During cycle 144: CRT draws in position 23
#  Current CRT row: #..#.###.....#.#....#...
#
#  End of cycle 144: finish executing 26
#  Starting sprite row: .........................###............
#  During cycle 145: CRT draws in position 24
#  Current CRT row: #..#.###.....#.#....#....
#
#  End of cycle 145: finish executing 26
#  Starting sprite row: .........................###............
#  During cycle 146: CRT draws in position 25
#  Current CRT row: #..#.###.....#.#....#....#
#
#  End of cycle 146: finish executing 10
#  Starting sprite row: .........###............................
#  During cycle 147: CRT draws in position 26
#  Current CRT row: #..#.###.....#.#....#....#.
#
#  End of cycle 147: finish executing 10
#  Starting sprite row: .........###............................
#  During cycle 148: CRT draws in position 27
#  Current CRT row: #..#.###.....#.#....#....#..
#
#  End of cycle 148: finish executing 27
#  Starting sprite row: ..........................###...........
#  During cycle 149: CRT draws in position 28
#  Current CRT row: #..#.###.....#.#....#....#..#
#
#  End of cycle 149: finish executing 27
#  Starting sprite row: ..........................###...........
#  During cycle 150: CRT draws in position 29
#  Current CRT row: #..#.###.....#.#....#....#..#.
#
#  End of cycle 150: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 151: CRT draws in position 30
#  Current CRT row: #..#.###.....#.#....#....#..#.#
#
#  End of cycle 151: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 152: CRT draws in position 31
#  Current CRT row: #..#.###.....#.#....#....#..#.#.
#
#  End of cycle 152: finish executing 17
#  Starting sprite row: ................###.....................
#  During cycle 153: CRT draws in position 32
#  Current CRT row: #..#.###.....#.#....#....#..#.#..
#
#  End of cycle 153: finish executing 17
#  Starting sprite row: ................###.....................
#  During cycle 154: CRT draws in position 33
#  Current CRT row: #..#.###.....#.#....#....#..#.#...
#
#  End of cycle 154: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 155: CRT draws in position 34
#  Current CRT row: #..#.###.....#.#....#....#..#.#....
#
#  End of cycle 155: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 156: CRT draws in position 35
#  Current CRT row: #..#.###.....#.#....#....#..#.#....#
#
#  End of cycle 156: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 157: CRT draws in position 36
#  Current CRT row: #..#.###.....#.#....#....#..#.#....##
#
#  End of cycle 157: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 158: CRT draws in position 37
#  Current CRT row: #..#.###.....#.#....#....#..#.#....###
#
#  End of cycle 158: finish executing -1
#  Starting sprite row: #.......................................
#  During cycle 159: CRT draws in position 38
#  Current CRT row: #..#.###.....#.#....#....#..#.#....###.
#
#  End of cycle 159: finish executing -1
#  Starting sprite row: #.......................................
#  During cycle 160: CRT draws in position 39
#  Current CRT row: #..#.###.....#.#....#....#..#.#....###..
#
#  End of cycle 160: finish executing -1
#  Starting sprite row: #.......................................
#  During cycle 161: CRT draws in position 0
#  Current CRT row: #
#
#  End of cycle 161: finish executing -1
#  Starting sprite row: #.......................................
#  During cycle 162: CRT draws in position 1
#  Current CRT row: #.
#
#  End of cycle 162: finish executing -1
#  Starting sprite row: #.......................................
#  During cycle 163: CRT draws in position 2
#  Current CRT row: #..
#
#  End of cycle 163: finish executing 2
#  Starting sprite row: .###....................................
#  During cycle 164: CRT draws in position 3
#  Current CRT row: #..#
#
#  End of cycle 164: finish executing 2
#  Starting sprite row: .###....................................
#  During cycle 165: CRT draws in position 4
#  Current CRT row: #..#.
#
#  End of cycle 165: finish executing 4
#  Starting sprite row: ...###..................................
#  During cycle 166: CRT draws in position 5
#  Current CRT row: #..#.#
#
#  End of cycle 166: finish executing 4
#  Starting sprite row: ...###..................................
#  During cycle 167: CRT draws in position 6
#  Current CRT row: #..#.#.
#
#  End of cycle 167: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 168: CRT draws in position 7
#  Current CRT row: #..#.#.#
#
#  End of cycle 168: finish executing 6
#  Starting sprite row: .....###................................
#  During cycle 169: CRT draws in position 8
#  Current CRT row: #..#.#.#.
#
#  End of cycle 169: finish executing 11
#  Starting sprite row: ..........###...........................
#  During cycle 170: CRT draws in position 9
#  Current CRT row: #..#.#.#..
#
#  End of cycle 170: finish executing 11
#  Starting sprite row: ..........###...........................
#  During cycle 171: CRT draws in position 10
#  Current CRT row: #..#.#.#..#
#
#  End of cycle 171: finish executing 31
#  Starting sprite row: ..............................###.......
#  During cycle 172: CRT draws in position 11
#  Current CRT row: #..#.#.#..#.
#
#  End of cycle 172: finish executing 31
#  Starting sprite row: ..............................###.......
#  During cycle 173: CRT draws in position 12
#  Current CRT row: #..#.#.#..#..
#
#  End of cycle 173: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 174: CRT draws in position 13
#  Current CRT row: #..#.#.#..#..#
#
#  End of cycle 174: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 175: CRT draws in position 14
#  Current CRT row: #..#.#.#..#..#.
#
#  End of cycle 175: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 176: CRT draws in position 15
#  Current CRT row: #..#.#.#..#..#.#
#
#  End of cycle 176: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 177: CRT draws in position 16
#  Current CRT row: #..#.#.#..#..#.#.
#
#  End of cycle 177: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 178: CRT draws in position 17
#  Current CRT row: #..#.#.#..#..#.#..
#
#  End of cycle 178: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 179: CRT draws in position 18
#  Current CRT row: #..#.#.#..#..#.#...
#
#  End of cycle 179: finish executing 14
#  Starting sprite row: .............###........................
#  During cycle 180: CRT draws in position 19
#  Current CRT row: #..#.#.#..#..#.#....
#
#  End of cycle 180: finish executing 19
#  Starting sprite row: ..................###...................
#  During cycle 181: CRT draws in position 20
#  Current CRT row: #..#.#.#..#..#.#....#
#
#  End of cycle 181: finish executing 19
#  Starting sprite row: ..................###...................
#  During cycle 182: CRT draws in position 21
#  Current CRT row: #..#.#.#..#..#.#....#.
#
#  End of cycle 182: finish executing 38
#  Starting sprite row: .....................................###
#  During cycle 183: CRT draws in position 22
#  Current CRT row: #..#.#.#..#..#.#....#..
#
#  End of cycle 183: finish executing 38
#  Starting sprite row: .....................................###
#  During cycle 184: CRT draws in position 23
#  Current CRT row: #..#.#.#..#..#.#....#...
#
#  End of cycle 184: finish executing 26
#  Starting sprite row: .........................###............
#  During cycle 185: CRT draws in position 24
#  Current CRT row: #..#.#.#..#..#.#....#....
#
#  End of cycle 185: finish executing 26
#  Starting sprite row: .........................###............
#  During cycle 186: CRT draws in position 25
#  Current CRT row: #..#.#.#..#..#.#....#....#
#
#  End of cycle 186: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 187: CRT draws in position 26
#  Current CRT row: #..#.#.#..#..#.#....#....#.
#
#  End of cycle 187: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 188: CRT draws in position 27
#  Current CRT row: #..#.#.#..#..#.#....#....#..
#
#  End of cycle 188: finish executing 27
#  Starting sprite row: ..........................###...........
#  During cycle 189: CRT draws in position 28
#  Current CRT row: #..#.#.#..#..#.#....#....#..#
#
#  End of cycle 189: finish executing 27
#  Starting sprite row: ..........................###...........
#  During cycle 190: CRT draws in position 29
#  Current CRT row: #..#.#.#..#..#.#....#....#..#.
#
#  End of cycle 190: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 191: CRT draws in position 30
#  Current CRT row: #..#.#.#..#..#.#....#....#..#.#
#
#  End of cycle 191: finish executing 29
#  Starting sprite row: ............................###.........
#  During cycle 192: CRT draws in position 31
#  Current CRT row: #..#.#.#..#..#.#....#....#..#.#.
#
#  End of cycle 192: finish executing 11
#  Starting sprite row: ..........###...........................
#  During cycle 193: CRT draws in position 32
#  Current CRT row: #..#.#.#..#..#.#....#....#..#.#..
#
#  End of cycle 193: finish executing 11
#  Starting sprite row: ..........###...........................
#  During cycle 194: CRT draws in position 33
#  Current CRT row: #..#.#.#..#..#.#....#....#..#.#...
#
#  End of cycle 194: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 195: CRT draws in position 34
#  Current CRT row: #..#.#.#..#..#.#....#....#..#.#....
#
#  End of cycle 195: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 196: CRT draws in position 35
#  Current CRT row: #..#.#.#..#..#.#....#....#..#.#....#
#
#  End of cycle 196: finish executing 22
#  Starting sprite row: .....................###................
#  During cycle 197: CRT draws in position 36
#  Current CRT row: #..#.#.#..#..#.#....#....#..#.#....#.
#
#  End of cycle 197: finish executing 22
#  Starting sprite row: .....................###................
#  During cycle 198: CRT draws in position 37
#  Current CRT row: #..#.#.#..#..#.#....#....#..#.#....#..
#
#  End of cycle 198: finish executing 0
#  Starting sprite row: ##......................................
#  During cycle 199: CRT draws in position 38
#  Current CRT row: #..#.#.#..#..#.#....#....#..#.#....#...
#
#  End of cycle 199: finish executing 0
#  Starting sprite row: ##......................................
#  During cycle 200: CRT draws in position 39
#  Current CRT row: #..#.#.#..#..#.#....#....#..#.#....#....
#
#  End of cycle 200: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 201: CRT draws in position 0
#  Current CRT row: #
#
#  End of cycle 201: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 202: CRT draws in position 1
#  Current CRT row: ##
#
#  End of cycle 202: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 203: CRT draws in position 2
#  Current CRT row: ###
#
#  End of cycle 203: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 204: CRT draws in position 3
#  Current CRT row: ###.
#
#  End of cycle 204: finish executing 1
#  Starting sprite row: ###.....................................
#  During cycle 205: CRT draws in position 4
#  Current CRT row: ###..
#
#  End of cycle 205: finish executing 4
#  Starting sprite row: ...###..................................
#  During cycle 206: CRT draws in position 5
#  Current CRT row: ###..#
#
#  End of cycle 206: finish executing 4
#  Starting sprite row: ...###..................................
#  During cycle 207: CRT draws in position 6
#  Current CRT row: ###..#.
#
#  End of cycle 207: finish executing 9
#  Starting sprite row: ........###.............................
#  During cycle 208: CRT draws in position 7
#  Current CRT row: ###..#..
#
#  End of cycle 208: finish executing 9
#  Starting sprite row: ........###.............................
#  During cycle 209: CRT draws in position 8
#  Current CRT row: ###..#..#
#
#  End of cycle 209: finish executing 5
#  Starting sprite row: ....###.................................
#  During cycle 210: CRT draws in position 9
#  Current CRT row: ###..#..#.
#
#  End of cycle 210: finish executing 5
#  Starting sprite row: ....###.................................
#  During cycle 211: CRT draws in position 10
#  Current CRT row: ###..#..#..
#
#  End of cycle 211: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 212: CRT draws in position 11
#  Current CRT row: ###..#..#..#
#
#  End of cycle 212: finish executing 12
#  Starting sprite row: ...........###..........................
#  During cycle 213: CRT draws in position 12
#  Current CRT row: ###..#..#..##
#
#  End of cycle 213: finish executing 16
#  Starting sprite row: ...............###......................
#  During cycle 214: CRT draws in position 13
#  Current CRT row: ###..#..#..##.
#
#  End of cycle 214: finish executing 16
#  Starting sprite row: ...............###......................
#  During cycle 215: CRT draws in position 14
#  Current CRT row: ###..#..#..##..
#
#  End of cycle 215: finish executing 16
#  Starting sprite row: ...............###......................
#  During cycle 216: CRT draws in position 15
#  Current CRT row: ###..#..#..##..#
#
#  End of cycle 216: finish executing 17
#  Starting sprite row: ................###.....................
#  During cycle 217: CRT draws in position 16
#  Current CRT row: ###..#..#..##..##
#
#  End of cycle 217: finish executing 17
#  Starting sprite row: ................###.....................
#  During cycle 218: CRT draws in position 17
#  Current CRT row: ###..#..#..##..###
#
#  End of cycle 218: finish executing 17
#  Starting sprite row: ................###.....................
#  During cycle 219: CRT draws in position 18
#  Current CRT row: ###..#..#..##..####
#
#  End of cycle 219: finish executing 17
#  Starting sprite row: ................###.....................
#  During cycle 220: CRT draws in position 19
#  Current CRT row: ###..#..#..##..####.
#
#  End of cycle 220: finish executing 19
#  Starting sprite row: ..................###...................
#  During cycle 221: CRT draws in position 20
#  Current CRT row: ###..#..#..##..####.#
#
#  End of cycle 221: finish executing 19
#  Starting sprite row: ..................###...................
#  During cycle 222: CRT draws in position 21
#  Current CRT row: ###..#..#..##..####.#.
#
#  End of cycle 222: finish executing 13
#  Starting sprite row: ............###.........................
#  During cycle 223: CRT draws in position 22
#  Current CRT row: ###..#..#..##..####.#..
#
#  End of cycle 223: finish executing 13
#  Starting sprite row: ............###.........................
#  During cycle 224: CRT draws in position 23
#  Current CRT row: ###..#..#..##..####.#...
#
#  End of cycle 224: finish executing 28
#  Starting sprite row: ...........................###..........
#  During cycle 225: CRT draws in position 24
#  Current CRT row: ###..#..#..##..####.#....
#
#  End of cycle 225: finish executing 28
#  Starting sprite row: ...........................###..........
#  During cycle 226: CRT draws in position 25
#  Current CRT row: ###..#..#..##..####.#.....
#
#  End of cycle 226: finish executing 27
#  Starting sprite row: ..........................###...........
#  During cycle 227: CRT draws in position 26
#  Current CRT row: ###..#..#..##..####.#.....#
#
#  End of cycle 227: finish executing 27
#  Starting sprite row: ..........................###...........
#  During cycle 228: CRT draws in position 27
#  Current CRT row: ###..#..#..##..####.#.....##
#
#  End of cycle 228: finish executing 31
#  Starting sprite row: ..............................###.......
#  During cycle 229: CRT draws in position 28
#  Current CRT row: ###..#..#..##..####.#.....##.
#
#  End of cycle 229: finish executing 31
#  Starting sprite row: ..............................###.......
#  During cycle 230: CRT draws in position 29
#  Current CRT row: ###..#..#..##..####.#.....##..
#
#  End of cycle 230: finish executing 31
#  Starting sprite row: ..............................###.......
#  During cycle 231: CRT draws in position 30
#  Current CRT row: ###..#..#..##..####.#.....##..#
#
#  End of cycle 231: finish executing 31
#  Starting sprite row: ..............................###.......
#  During cycle 232: CRT draws in position 31
#  Current CRT row: ###..#..#..##..####.#.....##..##
#
#  End of cycle 232: finish executing 32
#  Starting sprite row: ...............................###......
#  During cycle 233: CRT draws in position 32
#  Current CRT row: ###..#..#..##..####.#.....##..###
#
#  End of cycle 233: finish executing 32
#  Starting sprite row: ...............................###......
#  During cycle 234: CRT draws in position 33
#  Current CRT row: ###..#..#..##..####.#.....##..####
#
#  End of cycle 234: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 235: CRT draws in position 34
#  Current CRT row: ###..#..#..##..####.#.....##..####.
#
#  End of cycle 235: finish executing 36
#  Starting sprite row: ...................................###..
#  During cycle 236: CRT draws in position 35
#  Current CRT row: ###..#..#..##..####.#.....##..####.#
#
#  End of cycle 236: finish executing 3
#  Starting sprite row: ..###...................................
#  During cycle 237: CRT draws in position 36
#  Current CRT row: ###..#..#..##..####.#.....##..####.#.
#
#  End of cycle 237: finish executing 3
#  Starting sprite row: ..###...................................
#  During cycle 238: CRT draws in position 37
#  Current CRT row: ###..#..#..##..####.#.....##..####.#..
#
#  End of cycle 238: finish executing 3
#  Starting sprite row: ..###...................................
#  During cycle 239: CRT draws in position 38
#  Current CRT row: ###..#..#..##..####.#.....##..####.#...
#
#  End of cycle 239: finish executing 24
#  Starting sprite row: .......................###..............
#  During cycle 240: CRT draws in position 39
#  Current CRT row: ###..#..#..##..####.#.....##..####.#....

# %%
print(crt)
# Out:
# ###..###....##.#....####.#..#.#....###..
# #..#.#..#....#.#....#....#..#.#....#..#.
# ###..#..#....#.#....###..#..#.#....#..#.
# #..#.###.....#.#....#....#..#.#....###..
# #..#.#.#..#..#.#....#....#..#.#....#....
# ###..#..#..##..####.#.....##..####.#....
